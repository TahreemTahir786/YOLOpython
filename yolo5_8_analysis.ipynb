# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
yolo50 = pd.read_csv('/home/tahreem/Desktop/yolov5-torch/logs/yolonano/dataset_yolon_b0.csv')
yolo51 = pd.read_csv('/home/tahreem/Desktop/yolov5-torch/logs/yolosmall/dataset_yolos_b1.csv')
yolo52 = pd.read_csv('/home/tahreem/Desktop/yolov5-torch/logs/yolomedium/dataset_yolom_b2.csv')

dataset_yolos_b1.csv
yolo50.shape,yolo51.shape, yolo52.shape
# Out:
# ((1000, 8), (1000, 8), (1000, 8))

# %%
yolo80 = pd.read_csv('/home/tahreem/Desktop/yolov8/logs/dataset_yolo8n_b0.csv')
yolo81 = pd.read_csv('/home/tahreem/Desktop/yolov8/logs/dataset_yolo8n_b1.csv')
#yolo82 = pd.read_csv('/home/tahreem/Desktop/yolov8/logs/dataset_yolo8n_b2.csv')
yolo80.shape#, yolo81.shape
# Out:
# (1000, 10)

# %%
yolo80.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.721224e+09       nano     6.jpg               0.573383
# 1  1.721224e+09       nano     6.jpg               0.341900
# 2  1.721224e+09       nano     6.jpg               0.585923
# 3  1.721224e+09       nano     6.jpg               0.233505
# 4  1.721224e+09       nano     6.jpg               0.648946
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc   ram
# 0            5359.977245       5.962361  belgium  half       37.3  1000
# 1             365.174770       0.725332  belgium  half       37.3  1000
# 2             424.712896       1.041139  belgium  half       37.3  1000
# 3             465.583801       0.718743  belgium  half       37.3  1000
# 4             367.718697       1.038068  belgium  half       37.3  1000

# %%
plt.figure(figsize=(8,4))
plt.plot(yolo50.index, yolo50['Processing Delay (ms)'], label='Yolo 5')
plt.plot(yolo80.index[1:], yolo80['Processing Delay (ms)'][1:], label='Yolo 8')

#plt.title('Cost')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.legend()
plt.grid(True)
#plt.ylim([0,10])
plt.savefig('cost.pdf', format='pdf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(yolo51.index, yolo51['Processing Delay (ms)'], label='Yolo 5')
plt.plot(yolo81.index[1:], yolo81['Processing Delay (ms)'][1:], label='Yolo 8')

#plt.title('Cost')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.legend()
plt.grid(True)
#plt.ylim([0,10])
plt.savefig('cost.pdf', format='pdf')
plt.show()
